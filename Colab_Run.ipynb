# %% [markdown]
# # Colab Notebook for DL_project
#
# This notebook installs the required packages, mounts Google Drive, and runs the training script for the `DL_project` repository. Use GPU runtime in Colab.

# %% [markdown]
# ## 1. Install dependencies
# Run this cell first to install PyTorch, torchvision, OpenCV, pandas, scikit-learn, tqdm, and matplotlib.

# %%
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install -q opencv-python pandas scikit-learn tqdm matplotlib

# %% [markdown]
# ## 2. Mount Google Drive (optional)
# If your repository and dataset are stored in Drive, mount it here.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 3. Copy or access the project folder
# Update the path below if your project is stored in Google Drive. If you uploaded the repository directly, skip the copy and just set the working directory.

# %%
# %cd /content
# !mkdir -p /content/DL_project
# Uncomment and adjust the path below if the repo is in Google Drive
# !cp -r /content/drive/MyDrive/path/to/DL_project/* /content/DL_project/
# %cd /content/DL_project
# !ls

# %% [markdown]
# ## 4. Verify the notebook folder structure
# Ensure `MAAL.py`, `Attention.py`, and `common.py` are present in the current folder.

# %%
# !ls -1

# %% [markdown]
# ## 5. Run the training script
# Choose the script you want to run. The dataset path is currently set in `common.py` as `processed_dataset_MTL`. Adjust it if needed.

# %%
# %cd /content/DL_project
# !python MAAL.py
# !python Attention.py
